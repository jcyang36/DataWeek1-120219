# %% [markdown]
# # Module 4 Exercises - Data Visualization

# %% [markdown]
# ### Exercise 1:
#
# From the datasets folder, load the "dvddata.xlsx" file as a dataframe. Then rename the following columns (new column name is in parentheses):
# - \# of Clients (Clients)
# - Visits to each Client per Month (Visits)
# - Calls to each Client per month (Calls)
# - Emails to each Client per month (Emails)
# - \# of businesses in district (Business)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df=pd.read_excel("datasets/dvddata.xlsx",encoding="ISO=8859-1")
df.head()
# Out:
#        Salesperson  District Region  Sales  # of Clients  \
# 0     Addie Miller        52      A    393            16
# 1     Addie Miller        67      A    267            11
# 2     Addie Miller       104      A    148             4
# 3  Alexandra Jones        49      A    317            17
# 4   Alonzo Tennant        46      A    276            16
#
#     Visits to each Client per Month  Calls to each Client per month  \
# 0                                 2                               4
# 1                                 2                               1
# 2                                 1                               1
# 3                                 0                               7
# 4                                 2                               2
#
#    Emails to each Client per month  # of businesses in district
# 0                               30                          500
# 1                               14                          627
# 2                               17                          778
# 3                                1                          530
# 4                               22                          770

# %%
df.rename(columns={'# of Clients':'Clients','Visits to each Client per Month':'Visits','Calls to each client per month':'Calls','Emails to each Client per month':'Emails','# of businesses in district':'Businesses'},)
# Out:
#             Salesperson  District Region  Sales  Clients  \
# 0          Addie Miller        52      A    393       16
# 1          Addie Miller        67      A    267       11
# 2          Addie Miller       104      A    148        4
# 3       Alexandra Jones        49      A    317       17
# 4        Alonzo Tennant        46      A    276       16
# 5        Alonzo Tennant        90      A    347       16
# 6        Alonzo Tennant       100      A    253       11
# 7         Andrea Kraatz        97      A    216       13
# 8         Ann Dominguez        64      A    139        4
# 9            Anna Desai       113      A    128        4
# 10        Barbara Wales        91      A    262       19
# 11        Barbara Wales       124      A    215       10
# 12         Bessie Lewis        42      A    216       13
# 13         Bessie Lukas        38      A    327       13
# 14       Bessie Mcmanus        29      A    159       15
# 15       Bessie Mcmanus        55      A    185        7
# 16       Bessie Mcmanus       117      A    244       22
# 17        Caroline Boyd        70      A    526       20
# 18    Charlotte Simmons        27      A    470       17
# 19    Charlotte Simmons        74      A    415       22
# 20       Charmain Crisp        35      A    472       21
# 21      Christine Lopez        68      A     72        2
# 22  Christopher Alvardo        72      A    150        8
# 23  Christopher Alvardo        82      A     75        5
# 24      Connie Douglass        75      B    321       12
# 25      Cynthia Conklin        51      B    305       22
# 26      Cynthia Conklin       119      B    281       10
# 27      Cynthia Ellison        58      B    412       16
# 28        Deborah Seals        61      B    253        9
# 29        Deborah Seals        69      B    378       21
# ..                  ...       ...    ...    ...      ...
# 70           Lorna Kyle        94      C    105        4
# 71      Margaret Cooper       115      C    166       10
# 72      Margie Thrasher       118      C    295       21
# 73      Marilyn Sandler        43      C    248       11
# 74        Marisol Rosen       120      C    229        9
# 75        Martha Fabian        87      D    212       11
# 76         Mary Adamson        30      D    228       19
# 77        Mary Gauthier        60      D    193       12
# 78           Mary Smith        88      D     56        2
# 79          Megan Gault       125      D    263       14
# 80         Moses Chavez        81      D    149       10
# 81          Myrna Ellis        71      D    336       18
# 82         Nina Kennedy       107      D    311       16
# 83       Pamala Darrell        32      D    484       21
# 84      Rachel Griffith        83      D    457       18
# 85        Robert Liston       103      D    135        4
# 86        Ruby Meyerson        95      D     74        5
# 87       Sally Vineyard        59      D    457       20
# 88        Samuel Cuyler        96      D    232       19
# 89          Sarah Ellis        99      D    405       20
# 90           Sarah Hall        40      D    148        6
# 91     Sherry Davenport       123      D    391       15
# 92         Shirley Vick        86      D    303       22
# 93       Sonia Greenman        78      D    372       22
# 94        Susan J. Ward        37      D    244       11
# 95        Tammy Stowers       122      D    374       15
# 96         Terri Taylor        89      D    181       11
# 97         Terry Bonner       114      D    200        8
# 98        Terry Donnell        41      D    287       22
# 99        Trudy Vaughan        98      D    561       22
#
#      Visits to each Client per Month  Calls to each Client per month  Emails  \
# 0                                  2                               4      30
# 1                                  2                               1      14
# 2                                  1                               1      17
# 3                                  0                               7       1
# 4                                  2                               2      22
# 5                                  2                               8      21
# 6                                  1                               1       3
# 7                                  2                               6      11
# 8                                  2                               5      29
# 9                                  2                               6      26
# 10                                 2                               1      25
# 11                                 1                               0      10
# 12                                 2                               0      26
# 13                                 1                               4       5
# 14                                 2                               0      11
# 15                                 2                               7      26
# 16                                 0                               2       3
# 17                                 0                               7      23
# 18                                 0                               6      10
# 19                                 0                               6      18
# 20                                 2                               3      30
# 21                                 0                               5       3
# 22                                 1                               0      20
# 23                                 2                               7      28
# 24                                 2                               2       4
# 25                                 0                               0      24
# 26                                 2                               6      14
# 27                                 0                               0       1
# 28                                 1                               7       1
# 29                                 1                               0      29
# ..                               ...                             ...     ...
# 70                                 1                               7      19
# 71                                 0                               6       7
# 72                                 1                               7      17
# 73                                 2                               6      10
# 74                                 2                               0       2
# 75                                 1                               5      20
# 76                                 0                               5      27
# 77                                 0                               6      29
# 78                                 1                               0      20
# 79                                 1                               4       0
# 80                                 1                               5      27
# 81                                 2                               0      27
# 82                                 2                               8       3
# 83                                 1                               2      17
# 84                                 0                               7      11
# 85                                 1                               6       4
# 86                                 0                               1      21
# 87                                 1                               2      11
# 88                                 1                               3      18
# 89                                 0                               7      13
# 90                                 2                               5      22
# 91                                 2                               3      27
# 92                                 1                               1      16
# 93                                 0                               0       4
# 94                                 2                               3      10
# 95                                 0                               2      26
# 96                                 2                               2       9
# 97                                 2                               8      18
# 98                                 1                               6      21
# 99                                 1                               5      20
#
#     Businesses
# 0          500
# 1          627
# 2          778
# 3          530
# 4          770
# 5          288
# 6          875
# 7           25
# 8          926
# 9          596
# 10         783
# 11         739
# 12         720
# 13          91
# 14          33
# 15          57
# 16         400
# 17         645
# 18         361
# 19         213
# 20         234
# 21         909
# 22         584
# 23         634
# 24         705
# 25         383
# 26         279
# 27         489
# 28         518
# 29         167
# ..         ...
# 70         255
# 71          87
# 72         248
# 73         394
# 74         965
# 75         673
# 76         420
# 77         427
# 78         839
# 79         701
# 80         232
# 81         473
# 82          22
# 83         619
# 84         714
# 85         489
# 86         388
# 87         626
# 88         370
# 89         510
# 90         987
# 91         540
# 92         420
# 93         846
# 94         514
# 95         850
# 96         315
# 97         644
# 98         519
# 99         192
#
# [100 rows x 9 columns]

# %% [markdown]
# ### Exercise 2:
#
# Using the dataframe from the previous exercise, use the Seaborn library to create a scatterplot of the number of clients compared to the sales.

# %%
df.plot()

# %% [markdown]
# ### Exercise 3:
#
# Using the dataframe in the previous exercise, use the Seaborn library to make a boxplot of the Clients, Visits, Calls, and Emails columns. (**Hint**: Make a dataframe that only contains those columns)

# %% [markdown]
# ### Exercise 4:
#
# Using the dataframe from Exercise 3, use the Seaborn library to make a violin plot of sales per region.

# %% [markdown]
# ### Exercise 5:
#
# Using the dataframe in the previous exercise, create a swarm plot of sales per region.

# %% [markdown]
# ### Exercise 6:
#
# Using the dataframe in the previous exercise, make a correlation heatmap.

# %% [markdown]
# ### Exercise 7:
#
# Using the dataframe in the previous exercise, make a bar chart (count plot) of the regions.

# %% [markdown]
# ### Bonus
#
# Feel free to explore any other data visualizations using the Seaborn library.
